# %%
title = "ogs@jupyter-lab: AREHS: Salt H Process"
variables = ['pressure','v']
variable = "pressure"
coordinate = "x"

# %% [markdown]
# **ogs@jupyter-lab: AREHS: Salt H Process**

# %% [markdown]
# <!--- ![tu-dresden-blue.png](attachment:tu-dresden-blue.png) --->
# <img src="ogs-workflows.png" alt="drawing" width="300"/>

# %% [markdown]
# **Running ogs using [ogs6py](https://github.com/joergbuchwald/ogs6py)**

# %%
from ogs6py import ogs
#run ogs
print("===============")
print(">>> run ogs <<<")
model = ogs.OGS(PROJECT_FILE="arehs-salt-H_gravity_only.prj")
model.run_model(path="/home/ok/ogs/build/release/bin/",LOGFILE="example.log")
# Out:
# ===============
# >>> run ogs <<<
# OGS finished with project file arehs-salt-H_gravity_only.prj.
# Execution took 2.0212597846984863 s

# %% [markdown]
# **Extracting results using [VTUInterface](https://github.com/joergbuchwald/VTUinterface)**

# %%
# to read and process (point interpolation) vtu- and pvd-files 
import vtuIO
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.tri as tri
print("=====================")
print(">>> print results <<<")
pvdfile=vtuIO.PVDIO("arehs-salt-H_gravity_only.pvd", dim=2)
# define xaxis
xaxis =  [(i,0,0) for i in np.linspace(start=0.0, stop=6000., num=100)]
x = np.array(xaxis)[:,0]
diagonal = [(i,i,0) for i in np.linspace(start=0.0, stop=6000., num=100)]
r_diag = np.sqrt(np.array(diagonal)[:,0]**2+np.array(diagonal)[:,1]**2)
# define timestep
time = [3.1536e11]
fig, ax = plt.subplots(ncols=2, figsize=(12,5))
# read and interpolate from vtu-files listed in pvd
for t in time:
    xaxis_t = pvdfile.read_point_set_data(t, 'pressure', pointsetarray=xaxis)
    ax[0].plot(x, xaxis_t, label='t='+str(t))
    #function_diagonal_t = pvdfile.read_point_set_data(t, 'pressure', pointsetarray=diagonal)
    #ax[0].plot(r_diag, function_diagonal_t, label='t='+str(t))
    xaxis_t = pvdfile.read_point_set_data(t, 'v', pointsetarray=xaxis)
    ax[1].plot(x, xaxis_t, label='t='+str(t))
# plot formatting
ax[0].set_title(title)
ax[0].set_xlabel(coordinate)
ax[0].set_ylabel(variables[0])
ax[0].legend()
ax[0].grid()
ax[1].set_title(title)
ax[1].set_xlabel(coordinate)
ax[1].set_ylabel(variables[1])
ax[1].legend()
ax[1].grid()
plt.savefig("plot.png")
plt.show()
# Out:
# =====================
# >>> print results <<<
# arehs-salt-H_gravity_only.pvd

# %%
m_plot=vtuIO.VTUIO("arehs-salt-H_gravity_only_ts_10_t_315360000000.000000.vtu", dim=2)
triang=tri.Triangulation(m_plot.points[:,0],m_plot.points[:,1])
ux_plot = m_plot.get_point_field("pressure")
#uy_plot = m_plot.get_point_field("v").T[0]
#fig, ax = plt.subplots(ncols=2, figsize=(12,5))
fig, ax = plt.subplots(figsize=(12,5))
#contour_left = ax[0].tricontourf(triang, ux_plot)
contour_left = ax.tricontourf(triang, ux_plot)
#contour_right = ax[1].tricontourf(triang, uy_plot)
fig.colorbar(contour_left,label='$p$ / [Pa]')
#fig.colorbar(contour_right,ax=ax[1],label='$u_y$ / [m]')

# %%
import time
print(time.ctime())
# Out:
# Sun Jun 27 23:24:44 2021

# %% [markdown]
# **Results have been shown using [matplotlib](https://matplotlib.org/)**

# %% [markdown]
# **OGS links**
# - description: https://www.overleaf.com/project/601cf751130d22dd456ccd9a
# - project file: salt_dom_liquid_flow.prj
# - notebook compilation by OK (https://github.com/OlafKolditz/ogs-jupyter-lab)

# %% [markdown]
# **Credits**
# - Wenqing Wang for this benchmark set up
# - Jörg Buchwald for ogs6py and VTUInterface (JOSS review pending) https://joss.theoj.org/papers/6ddcac13634c6373e6e808952fdf4abc
