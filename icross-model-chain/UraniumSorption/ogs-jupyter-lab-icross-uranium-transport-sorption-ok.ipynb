# %% [markdown]
# **ogs@jupyter-lab: C process: U(6) Transport-sorption Process**

# %%
PATH = "/home/ok/ogs-jupyter-lab-dev"

# %% [markdown]
# <table><tr>
# <td> <img src="ogs-workflows.png" alt="Drawing" style="width: 300px;"/> </td>
# <td> <img src="icross-logo-ok.png" alt="Drawing" style="width: 100px;"/> </td>
# </tr></table>

# %% [markdown]
# **Model #1: Chemical calculations by calling Phreeqc during the runtime**

# %%
from ogs6py import ogs

print("===============")
print(">>> run ogs <<<")

model = ogs.OGS(PROJECT_FILE="./full_coupling/RadionuclideSorption.prj")
#model.run_model(path="/home/ok/ogs/build/release/bin/")
model.run_model(path="/home/ok/ogs-branches/renchao/build/release/bin")
# Out:
# ===============
# >>> run ogs <<<
# OGS finished with project file ./full_coupling/RadionuclideSorption.prj.
# Execution took 23.052903175354004 s

# %%
import vtuIO
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm

plt.style.use('../notebook.mplstyle')
print("=====================")
print(">>> print results <<<")

#pvdfile=vtuIO.PVDIO('.',"RadionuclideSorption_full_coupling.pvd", dim=1)
pvdfile=vtuIO.PVDIO("RadionuclideSorption_full_coupling.pvd", dim=1)

xaxis =  [(i,0,0) for i in np.linspace(start=0.0, stop=15, num=100)]
r_x = np.array(xaxis)[:,0]
time = [0,23000,46000,69000,92000,115000]

color=iter(cm.rainbow(np.linspace(0,1,len(time))))
for t, color in zip(time, color):
    function_xaxis_t = pvdfile.read_point_set_data(t, 'U(6)', pointsetarray=xaxis)
    plt.plot(r_x, function_xaxis_t/1000, label='t={}s'.format(t), color=color)
    
plt.title("Full coupling: Evolution of U(6) profile")
#plt.xscale('log')
plt.xlim(0,15)
plt.xlabel('x [m]')
plt.ylabel('U(6) Concentration [mol/L]')

plt.legend()
plt.grid()

#plt.savefig("profile_phreeqc_coupling.png")
plt.show()
# Out:
# =====================
# >>> print results <<<
# RadionuclideSorption_full_coupling.pvd

# %% [markdown]
# **Model #2: Chemical calculation by the look-up table approach.**
# **This simulation is performed along with a sparse look-up table.**

# %%
print("===============")
print(">>> run ogs <<<")

model = ogs.OGS(PROJECT_FILE="./sparse_lookup_table/RadionuclideSorption.prj")
#model = ogs.OGS(PROJECT_FILE="RadionuclideSorption.prj")
#model.run_model(path="/home/ok/ogs/build/release/bin/")
model.run_model(path="/home/ok/ogs-branches/renchao/build/release/bin")
# Out:
# ===============
# >>> run ogs <<<
# OGS finished with project file ./sparse_lookup_table/RadionuclideSorption.prj.
# Execution took 0.3447682857513428 s

# %%
print("=====================")
print(">>> print results <<<")

#pvdfile=vtuIO.PVDIO(".", "RadionuclideSorption_sparse_table.pvd", dim=1)
pvdfile=vtuIO.PVDIO("RadionuclideSorption_sparse_table.pvd", dim=1)

xaxis =  [(i,0,0) for i in np.linspace(start=0.0, stop=15, num=100)]
r_x = np.array(xaxis)[:,0]
time = [0,23000,46000,69000,92000,115000]

color=iter(cm.rainbow(np.linspace(0,1,len(time))))
for t, color in zip(time, color):
    function_xaxis_t = pvdfile.read_point_set_data(t, 'U(6)', pointsetarray=xaxis)
    plt.plot(r_x, function_xaxis_t/1000, label='t={}s'.format(t), color=color)
    
plt.title("Sparse look-up table: Evolution of U(6) profile")
#plt.xscale('log')
plt.xlim(0,15)
plt.xlabel('x [m]')
plt.ylabel('U(6) Concentration [mol/L]')

plt.legend()
plt.grid()

#plt.savefig("profile_sparse_table.png")
plt.show()
# Out:
# =====================
# >>> print results <<<
# RadionuclideSorption_sparse_table.pvd

# %% [markdown]
# **Model #3: Chemical calculation by the look-up table approach.**
# **This simulation is performed along with a more dense look-up table.**

# %%
print("===============")
print(">>> run ogs <<<")

model = ogs.OGS(PROJECT_FILE="./dense_lookup_table/RadionuclideSorption.prj")
#model.run_model(path="/home/ok/ogs/build/release/bin/")
model.run_model(path="/home/ok/ogs-branches/renchao/build/release/bin")
# Out:
# ===============
# >>> run ogs <<<
# OGS finished with project file ./dense_lookup_table/RadionuclideSorption.prj.
# Execution took 0.3727853298187256 s

# %%
print("=====================")
print(">>> print results <<<")

#pvdfile=vtuIO.PVDIO(".", "RadionuclideSorption_dense_table.pvd", dim=1)
pvdfile=vtuIO.PVDIO("RadionuclideSorption_dense_table.pvd", dim=1)

xaxis =  [(i,0,0) for i in np.linspace(start=0.0, stop=15, num=100)]
r_x = np.array(xaxis)[:,0]
time = [0,23000,46000,69000,92000,115000]

color=iter(cm.rainbow(np.linspace(0,1,len(time))))
for t, color in zip(time, color):
    function_xaxis_t = pvdfile.read_point_set_data(t, 'U(6)', pointsetarray=xaxis)
    plt.plot(r_x, function_xaxis_t/1000, label='t={}s'.format(t), color=color)
    
plt.title("Dense look-up table: Evolution of U(6) profile")
#plt.xscale('log')
plt.xlim(0,15)
plt.xlabel('x [m]')
plt.ylabel('U(6) Concentration [mol/L]')

plt.legend()
plt.grid()

#plt.savefig("profile_dense_table.png")
plt.show()
# Out:
# =====================
# >>> print results <<<
# RadionuclideSorption_dense_table.pvd

# %% [markdown]
# **Comparison of different approaches in terms of U(6) profile**

# %%
#pvd_full_coupling=vtuIO.PVDIO(".", "RadionuclideSorption_full_coupling.pvd", dim=1)
#pvd_sparse_table=vtuIO.PVDIO(".", "RadionuclideSorption_sparse_table.pvd", dim=1)
#pvd_dense_table=vtuIO.PVDIO(".", "RadionuclideSorption_dense_table.pvd", dim=1)
pvd_full_coupling=vtuIO.PVDIO("RadionuclideSorption_full_coupling.pvd", dim=1)
pvd_sparse_table=vtuIO.PVDIO("RadionuclideSorption_sparse_table.pvd", dim=1)
pvd_dense_table=vtuIO.PVDIO("RadionuclideSorption_dense_table.pvd", dim=1)


xaxis =  [(i,0,0) for i in np.linspace(start=0.0, stop=15, num=100)]
r_x = np.array(xaxis)[:,0]

time = 115000

func_full_coupling = pvd_full_coupling.read_point_set_data(time, 'U(6)', pointsetarray=xaxis)
func_sparse_table = pvd_sparse_table.read_point_set_data(time, 'U(6)', pointsetarray=xaxis)
func_dense_table = pvd_dense_table.read_point_set_data(time, 'U(6)', pointsetarray=xaxis)

plt.plot(r_x, func_full_coupling/1000, label='full coupling', color='k')
plt.plot(r_x, func_sparse_table/1000, label='sparse lookup table', linestyle='-.')
plt.plot(r_x, func_dense_table/1000, label='more dense lookup table', linestyle='--', color='r')

title_str="U(6) profiles at t={} s".format(time)
plt.title(title_str)

#plt.xscale('log')
plt.xlim(0,15)
plt.xlabel('x [m]')
plt.ylabel('U(6) Concentration [mol/L]')

plt.legend()
plt.grid()

plt.savefig("profile_dense_table.png")
plt.show()
# Out:
# RadionuclideSorption_full_coupling.pvd
# RadionuclideSorption_sparse_table.pvd
# RadionuclideSorption_dense_table.pvd

# %% [markdown]
# **OGS links**
# - description: https://www.opengeosys.org/docs/benchmarks/reactive-transport/radionuclide/radionuclide/
# - notebook implementation by Renchao Lu: https://github.com/OlafKolditz/ogs-jupyter-lab/blob/main/icross-model-chain/UraniumSorption/ogs-jupyter-lab-icross-uranium-transport-sorption.ipynb
# - notebook concept by OK: https://github.com/OlafKolditz/ogs-jupyter-lab

# %% [markdown]
# **Credits**
# - Renchao Lu for this benchmark set up
# - Jörg Buchwald for ogs6py and VTUInterface (https://joss.theoj.org/papers/6ddcac13634c6373e6e808952fdf4abc)
# - Frameworks acknowledgements: OGS, Python, Jupyter, matplotlib
