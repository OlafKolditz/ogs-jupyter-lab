# %% [markdown]
# **ogs@jupyter-lab: C process: Cs Transport-sorption Process**

# %% [markdown]
# <table><tr>
# <td> <img src="../ogs-workflows.png" alt="Drawing" style="width: 300px;"/> </td>
# <td> <img src="../icross-logo-ok.png" alt="Drawing" style="width: 100px;"/> </td>
# </tr></table>

# %% [markdown]
# **Model #1: Chemical calculations by calling Phreeqc during the runtime**

# %% [markdown]
# Total simulation time is about 21 hrs. on a single CPU core (Intel(R) Xeon(R) @ 2.40GHz). Therefore, simulation is completed externally and only the results are shown. To obtain the results, please run the file `caesium_phreeqc/caesium.prj`.

# %% [markdown]
# **Model #1: Plot results using vtuIO**

# %% [markdown]
# OGS-6#Phreeqc results are compared to standalone PHREEQC results published in [this paper](https://rdcu.be/cyeMV):
#
# Águila, J.F., Montoya, V., Samper, J. et al. Modeling cesium migration through Opalinus clay: a benchmark for single- and multi-species sorption-diffusion models. Comput Geosci 25, 1405–1436 (2021). https://doi.org/10.1007/s10596-021-10050-5

# %%
import vtuIO
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
import matplotlib as mpl
import pandas as pd
mpl.rcParams['figure.dpi'] = 300

plt.style.use('caesium.mplstyle')
print("=====================")
print(">>> print results <<<")

pvdfile = vtuIO.PVDIO("./caesium_phreeqc/results/out.pvd", dim=1)

component = 'Cs'
points={'pt0': (0.00101818,0.0,0.0), 'pt1': (0.00509091,0.0,0.0), 'pt2': (0.00701414,0.0,0.0), 'pt3': (0.00905051,0.0,0.0)}
time = pvdfile.timesteps
Cs_breakthrough = pvdfile.read_time_series(component, points)

f, (ax1, ax2) = plt.subplots(1, 2, sharey=False)

ax1.set_title("a) Linear scale")
#plot ogs results
ax1.plot(time, Cs_breakthrough["pt0"], "b-", label="1 mm (OGS-6#Phreeqc)")
ax1.plot(time, Cs_breakthrough["pt1"], "b--", label="5 mm (OGS-6#Phreeqc)")
ax1.plot(time, Cs_breakthrough["pt2"], "b-.", label="7 mm (OGS-6#Phreeqc)")
ax1.plot(time, Cs_breakthrough["pt3"], "b:", label="9 mm (OGS-6#Phreeqc)")
#plot phreeqc results
phr_results = pd.read_csv("breakthrough_phreeqc.csv")
ax1.plot(phr_results['time'], phr_results['cs_1mm'], label="1 mm (PHREEQC)", color="red", linestyle="-")
ax1.plot(phr_results['time'], phr_results['cs_5mm'], label="5 mm (PHREEQC)", color="red", linestyle="--")
ax1.plot(phr_results['time'], phr_results['cs_7mm'], label="7 mm (PHREEQC)", color="red", linestyle="-.")
ax1.plot(phr_results['time'], phr_results['cs_9mm'], label="9 mm (PHREEQC)", color="red", linestyle=":")
ax1.set_xscale('log')
ax1.set_xlim(86400, 86400*10000)
ax1.set_xlabel('time [days]')
x_labels = [1, 10, 100, 1000, 10000]
x_ticks = [86400, 864000, 8640000, 86400000, 864000000]
ax1.set_xticks(x_ticks)
ax1.set_xticklabels(x_labels)
ax1.set_ylabel('{} concentration [mol/kgw]'.format(component))

ax2.set_title("a) Log scale")
#plot ogs results
ax2.plot(time, Cs_breakthrough["pt0"], "b-", label="1 mm (OGS-6#Phreeqc)")
ax2.plot(time, Cs_breakthrough["pt1"], "b--", label="5 mm (OGS-6#Phreeqc)")
ax2.plot(time, Cs_breakthrough["pt2"], "b-.", label="7 mm (OGS-6#Phreeqc)")
ax2.plot(time, Cs_breakthrough["pt3"], "b:", label="9 mm (OGS-6#Phreeqc)")
#plot phreeqc results
ax2.plot(phr_results['time'], phr_results['cs_1mm'], label="1 mm (PHREEQC)", color="red", linestyle="-")
ax2.plot(phr_results['time'], phr_results['cs_5mm'], label="5 mm (PHREEQC)", color="red", linestyle="--")
ax2.plot(phr_results['time'], phr_results['cs_7mm'], label="7 mm (PHREEQC)", color="red", linestyle="-.")
ax2.plot(phr_results['time'], phr_results['cs_9mm'], label="9 mm (PHREEQC)", color="red", linestyle=":")
ax2.set_xscale('log')
ax2.set_xlim(86400, 86400*10000)
ax2.set_yscale('log')
ax2.set_ylim(1e-11, 1e-6)
ax2.set_xlabel('time [days]')
x_labels = [1, 10, 100, 1000, 10000]
x_ticks = [86400, 864000, 8640000, 86400000, 864000000]
ax2.set_xticks(x_ticks)
ax2.set_xticklabels(x_labels)

ax1.legend()
plt.tight_layout()
# plt.savefig("thumbnail-cs01.png", dpi=96)
plt.show()
# Out:
# ...
# >>> print results <<<
# ./caesium_phreeqc/results/out.pvd

# %% [markdown]
# **Model #2: Chemical calculation with the look-up table approach. This simulation is performed with a dense look-up table.**

# %% [markdown]
# Simulation time with the dense look-up table is greatly reduced from 21h to about 0.5 hrs (42 times faster). To obtain the results, please run the file `caesium_table/caesium.prj`.

# %%
import vtuIO
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
import matplotlib as mpl
import pandas as pd

mpl.rcParams["figure.dpi"] = 300

plt.style.use("../notebook.mplstyle")
print("=====================")
print(">>> print results <<<")

pvdfile_table = vtuIO.PVDIO("./caesium_table/results/out.pvd", dim=1)

component = "Cs"
points = {
    "pt0": (0.00101818, 0.0, 0.0),
    "pt1": (0.00509091, 0.0, 0.0),
    "pt2": (0.00701414, 0.0, 0.0),
    "pt3": (0.00905051, 0.0, 0.0),
}
time = pvdfile.timesteps
Cs_phreeqc_breakthrough = pvdfile.read_time_series(component, points)
Cs_table_breakthrough = pvdfile_table.read_time_series(component, points)

# plot ogs#phreeqc results
plt.plot(time, Cs_phreeqc_breakthrough["pt0"], "b-", linewidth=3, label="1 mm (OGS-6#Phreeqc)")
plt.plot(time, Cs_phreeqc_breakthrough["pt1"], "b--", linewidth=3, label="5 mm (OGS-6#Phreeqc)")
plt.plot(time, Cs_phreeqc_breakthrough["pt2"], "b-.", linewidth=3, label="7 mm (OGS-6#Phreeqc)")
plt.plot(time, Cs_phreeqc_breakthrough["pt3"], "b:", linewidth=3, label="9 mm (OGS-6#Phreeqc)")

# plot look-up table results
plt.plot(time, Cs_table_breakthrough["pt0"], "r-", linewidth=1, label="1 mm (OGS-6 look-up table)")
plt.plot(time, Cs_table_breakthrough["pt1"], "r--", linewidth=1, label="5 mm (OGS-6 look-up table)")
plt.plot(time, Cs_table_breakthrough["pt2"], "r-.", linewidth=1, label="7 mm (OGS-6 look-up table)")
plt.plot(time, Cs_table_breakthrough["pt3"], "r:", linewidth=1, label="9 mm (OGS-6 look-up table)")

plt.xscale("log")
plt.xlim(86400, 86400 * 10000)
# plt.yscale("log")
# plt.ylim(1e-11, 1e-6)
titlestring = "Look up table vs full coupling".format(component)
plt.title(titlestring)
plt.xlabel("time [days]")
x_labels = [1, 10, 100, 1000, 10000]
x_ticks = [86400, 864000, 8640000, 86400000, 864000000]
plt.xticks(x_ticks, x_labels)

plt.ylabel("{} concentration [mol/kgw]".format(component))
plt.legend()
plt.tight_layout()
# plt.savefig("thumbnail-cs01-LT.png", dpi=96)
plt.show()
# Out:
# ...
# >>> print results <<<
# ./caesium_table/results/out.pvd

# %% [markdown]
# **OGS links**
# - notebook draft by OK: https://github.com/OlafKolditz/ogs-jupyter-lab

# %% [markdown]
# **Credits**
# - Jaime Garibay-Rodriguez for this benchmark set up and Renchao Lu for the look-up table implementation in OGS-6.
# - Jörg Buchwald for ogs6py and VTUInterface (https://joss.theoj.org/papers/6ddcac13634c6373e6e808952fdf4abc)
# - Frameworks acknowledgements: OGS, Python, Jupyter, matplotlib
