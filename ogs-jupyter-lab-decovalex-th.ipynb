# %% [markdown]
# **ogs-jupyter-lab: DECOVALEX TH process: FEBEX type repository**

# %% [markdown]
# <!--- ![tu-dresden-blue.png](attachment:tu-dresden-blue.png) --->
# <img src="ogs-jupyter-lab+decovalex-thmc.png" alt="drawing" width="300"/>

# %% [markdown]
# **Prerequisites**
#
# ...

# %% [markdown]
# **Description**
#
# DECOVALEX is an international benchmarking project for the DEvelopment of COupled models and their VALidation against Experiments in geosystems with an emphasis on deep geological repositories (https://decovalex.org/). The present test case comes from Task D (BMT3: Long term changes in EDZ due to THM and THC processes) of the 4th phase DECOVALEX-THMC (2004-2007) (https://decovalex.org/D-THMC/index.html).
#
# The purpose of task D is to simulate coupled THM processes in the FEBEX type of nuclear repository, which seals the waste cansitor with bentonite in the cells in the granite, in order to assess the safety of the repository. Therfore, the water vapour flow and the swelling stress in the initially partially water saturated bentonite, and the pore pressure and stress changes in the fully water saturated near field host rock (granite), which are induced by the heat power of the nuclear waste canister, are highly focused in the simulation.
#
# In order to test the imlementation of TH process, which is for the non-isthomeral fully saturated liquid flow in the porous medium, this test only condiders the changes of temperature and pore pressure in the fully water saturated near field host rock within the specification of Task D of the DECOVALEX-THMC project.

# %% [markdown]
# **Governing equations**
#
# The governing eqautions about the non-isthomeral fully saturated liquid flow in the porous medium are given by
#
# $$\phi \rho_L\alpha_p\dfrac{\partial p}{\partial t}-\nabla\left(\rho_L\frac{\mathbf{k}}{\mu}(\nabla p -\rho_L \mathbf{g})\right)-\rho_L\left(\phi \alpha_T^L +3 (1-\phi) \alpha_T^s\right) \dfrac{\partial T}{\partial t}=Q_H$$
# for the mass balance, and
# $$(\rho c_p)'\dfrac{\partial T}{\partial t}-\nabla\left({\mathbf{\lambda}_T} \nabla T \right)
# +\phi \rho_L c_p^L \nabla T \cdot \mathbf{v}_L=Q_T$$
# for the egergy balance,
# where
# * $\alpha_p$ is the specific storage,
# * $p$ is the water pressure,
# * $\rho_L$ is the water density,
# * $\phi$ is the effective
# * porosity of the media,
# * $\mu$ is the viscosity of flow,
# * $\mathbf k$ denotes intrinsic permeability,
# * $\mathbf g$ is the gravity force by density,
# * $\alpha_T^L$ is the thermal expansivity of liqiud,
# * $\alpha_T^s$ is the linear thermal expansivity of solid,
# * $Q_H$ is the sink/source term of the mass balance equation,
# * $(\rho c_p)'$ is the volumetric heat capacity,
# * $\mathbf{\lambda}_T$ is the effictive thermal conductivity,
# * $c_p^L$ is the specific heat capacity of liquid,
# * $\mathbf{v}_L =\frac{\mathbf{k}}{\mu}(\nabla p -\rho_L \mathbf{g})$ is the Darcy velocity,
# * $Q_H$ is the sink/source term of the energy balance equation.

# %% [markdown]
# **Test definition**
#
# This test is a simplification of one of the benchmarks of Task D of the DECOVALEX-THMC, which is aimed to to test the staggered scheme for TH process in ogs 6. The simplifications are
# * resizing the domain to an area that can represent the near field of an installed nuclear water canister,
# * assuming the the betonite is fully saturated from the beginning,
# * bentonite is in the fully stage,
# * ignoring the mechanical process.
#
# With such simplifications, the domain of the test is illustrated in the following figure, which has two material groups of elements, one for bentonite in red color, one for rock mass in blue color.
#
# <img src="decovalex_TH_domain.png" alt="drawing" width="200"/>

# %% [markdown]
# **Material properties**
#
# The material properties are given in the following table:
# <table>
# <caption>Material properties</caption>
# <thead>
# <tr class="header">
# <th align="left">Property</th>
# <th align="left">Unit</th>
# <th align="left">Value</th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td align="left"><em>Water</em></td>
# <td align="left"></td>
# <td align="left"></td>
# </tr>
# <tr class="even">
# <td align="left">Density</td>
# <td align="left"><span class="math inline">kg/m<sup>3</sup></span></td>
# <td align="left">1000 (1-4.3 ⋅ 10<sup>−4</sup>(T-293))</td>
# </tr>
# <tr class="even">
# <td align="left">Thermal conductivity</td>
# <td align="left"><span class="math inline">w/(mK)</span></td>
# <td align="left">0.6</td>
# </tr>
# <tr class="odd">
# <td align="left">Specific heat capacity</td>
# <td align="left"><span class="math inline">J/(kg K)</span></td>
# <td align="left">4000.0</td>
# </tr>
# </tr>
# <tr class="even">
# <td align="left">Viscosity</td>
# <td align="left"><span class="math inline">Pa s</span></td>
# <td align="left">10  ⋅ <sup>-3</sup></td>
# </tr>
# <tr class="odd">
# <td align="left"><em>Bentonite</em></td>
# <td align="left"></td>
# <td align="left"></td>
# </tr>
# <tr class="even">
# <td align="left">Density</td>
# <td align="left"><span class="math inline">kg/m<sup>3</sup></span></td>
# <td align="left">1600</td>
# </tr>
# <tr class="odd">
# <td align="left">Porosity</td>
# <td align="left">-</td>
# <td align="left">0.01</td>
# </tr>
# <tr class="even">
# <td align="left">Thermal conductivity</td>
# <td align="left"><span class="math inline">w/(mK)</span></td>
# <td align="left">3</td>
# </tr>
# <tr class="odd">
# <td align="left">Specific heat capacity</td>
# <td align="left"><span class="math inline">J/(kg K)</span></td>
# <td align="left">3</td>
# </tr>
# <tr class="even">
# <td align="left">Saturated permeability</td>
# <td align="left"><span class="math inline">m<sup>2</sup></span></td>
# <td align="left"><span class="math inline">2.0 ⋅ 10<sup>−21</sup></span></td>
# </tr>
# <tr class="odd">
# <td align="left"><em>Granite</em></td>
# <td align="left"></td>
# <td align="left"></td>
# </tr>
# <tr class="even">
# <td align="left">Density</td>
# <td align="left"><span class="math inline">kg/m<sup>3</sup></span></td>
# <td align="left">2700</td>
# </tr>
# <tr class="odd">
# <td align="left">Porosity</td>
# <td align="left">-</td>
# <td align="left">0.41</td>
# </tr>
# <tr class="even">
# <td align="left">Thermal conductivity</td>
# <td align="left"><span class="math inline">w/(mK)</span></td>
# <td align="left">3</td>
# </tr>
# <tr class="odd">
# <td align="left">Specific heat capacity</td>
# <td align="left"><span class="math inline">J/(kg K)</span></td>
# <td align="left">900</td>
# </tr>
# <tr class="even">
# <td align="left">Saturated permeability</td>
# <td align="left"><span class="math inline">m<sup>2</sup></span></td>
# <td align="left"><span class="math inline">10<sup>−17</sup></span></td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# **Boundary conditions**
#
# A heat power (see the figure below), which is generated by the nuclear waste with one million year variation, is applied onto the inner arc of the annulus sector as a Neumann boundary condition of the energy balance equation.
# <img src="decovalex_thmc_heat.png" alt="drawing" width="250"/>
#
# On the top boundary, the boundary conditions are $p = 4.3\cdot10^6$ Pa, $T = 294$ K. While on the bottom boundary, the boundary conditions are set as $p = 4.7\cdot 10^6$ Pa, $T = 310$ K. The initial conditions are given as $p = 4.7 \cdot 10^6$ Pa, $T = 298$ K.

# %% [markdown]
# **Inspector**

# %%
import pyvista as pv
file_vtu_input = "th_decovalex.vtu"
mesh = pv.read(file_vtu_input)
print("inspecting vtu input file: " + str(file_vtu_input))
mesh
# Out:
# inspecting vtu input file: th_decovalex.vtu
# UnstructuredGrid (0x7fcb2831e2e0)
#   N Cells:	766
#   N Points:	424
#   X Bounds:	0.000e+00, 1.750e+01
#   Y Bounds:	-1.750e+01, 1.750e+01
#   Z Bounds:	0.000e+00, 0.000e+00
#   N Arrays:	6

# %%
from ogs6py import ogs
project_file = "th_decovalex.prj"
print("inspecting prj file: " + str(project_file) + " > xml-tree")
model = ogs.OGS(INPUT_FILE=project_file,PROJECT_FILE=project_file)
print("PROCESS: ")
model.tree.find("./processes/process/type").text
print("PARAMETERS: ")
[i.text for i in model.tree.findall("./parameters/parameter/name")]
# Out:
# inspecting prj file: th_decovalex.prj > xml-tree
# PROCESS:
# PARAMETERS:
# ['p0',
#  'p_bc_top',
#  'p_bc_bottom',
#  'lambda',
#  'lambda_fluid',
#  'c_p',
#  'rho_solid',
#  'n0',
#  'n1',
#  'T0',
#  'TB_top',
#  'TB_bottom',
#  'mu0',
#  'mu1',
#  'hpower_on_arc',
#  'heat_power',
#  'heat_power_c']

# %%
import matplotlib.pyplot as plt
import numpy as np
import vtk
from vtk.util.numpy_support import vtk_to_numpy
import matplotlib.tri as tri
file_vtu = "th_decovalex.vtu"
print("inspecting: " + str(file_vtu) + ": mesh and initial conditions")
#file
reader = vtk.vtkXMLUnstructuredGridReader()
reader.SetFileName(file_vtu)
reader.Update()  # Needed because of GetScalarRange
data = reader.GetOutput()
temperature = data.GetPointData().GetArray("T_ref")
pressure = data.GetPointData().GetArray("p_ref")
#points
points = data.GetPoints()
npts = points.GetNumberOfPoints()
x = vtk_to_numpy(points.GetData())
triang = tri.Triangulation(x[:,0], x[:,1])
#cells
triangles=  vtk_to_numpy(data.GetCells().GetData())
ntri = triangles.size//4  # number of cells
tri = np.take(triangles,[n for n in range(triangles.size) if n%4 != 0]).reshape(ntri,3)
#plots
fig, ax = plt.subplots(ncols=3, figsize=(14,8))
#plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9, wspace=0.4, hspace=0.6)
plt.subplots_adjust(wspace=0.5)
#mesh
ax[0].triplot(x[:,0], x[:,1], tri)
ax[1].tricontour(x[:,0], x[:,1], tri, pressure, 16);
contour_right = ax[2].tricontour(triang, pressure)
fig.colorbar(contour_right,ax=ax[1],label='$p$ / [Pa]')
ax[2].tricontourf(x[:,0], x[:,1], tri, temperature, 12);
contour_right = ax[2].tricontourf(triang, temperature)
fig.colorbar(contour_right,ax=ax[2],label='$T$ / [K]')
plt.savefig("figures.png")
# Out:
# inspecting: th_decovalex.vtu: mesh and initial conditions

# %% [markdown]
# **Running ogs**

# %%
import multiprocessing
from ogs6py import ogs
PATH_OGS = "/home/ok/ogs/build/release/bin/"
PATH_SINGULARITY = "/usr/bin/"
PATH_CONTAINER = "/home/ok/ogs/container/gcc-10-openmpi-4.0.5-system-cmake-f0a156cb-4a3437aac8bc.sif"
PROJECT_FILE = "th_decovalex.prj"
model = ogs.OGS(INPUT_FILE=project_file,PROJECT_FILE=project_file)

mode=3
###
#1 run ogs executeable
if mode==1:
    print("run ogs executeable")
    model.run_model(path=PATH_OGS,logfile="console.log")
#model.run_model(args="-o ./full_coupling")
###
#2 run ogs container
if mode==2:
    print("run ogs container")
    model.run_model(path=PATH_SINGULARITY,container_path=PATH_CONTAINER,logfile="console.log")
###
#3
if mode==3:
    print("run ogs container: multiprocessing")
    ogs_process = multiprocessing.Process(
        target=model.run_model,
        kwargs={"path":PATH_SINGULARITY, "container_path":PATH_CONTAINER,"logfile":"example.log"})
    ogs_process.start()
###
#4 run jupyter container
if mode==4:
    print("run jupyter container")
    # !ogs PROJECT_FILE
# Out:
# run ogs container: multiprocessing
# OGS finished with project file th_decovalex.prj.
# Execution took 4.073657751083374 s

# %% [markdown]
# **Analysis**

# %%
print("Calling Paraview")
file_pvsm = "th_decovalex.pvsm"
#!paraview file_pvsm ?
#!paraview th_decovalex.pvsm
import multiprocessing
def worker():
    # !paraview th_decovalex.pvsm
    return
p = multiprocessing.Process(target=worker)
p.start()
# Out:
# Calling Paraview
# qt5ct: using qt5ct plugin
# qt5ct: D-Bus global menu: no

# %%
theme = "Profile plot"
print(theme)
import vtuIO
file_pvd = "th_decovalex.pvd"
pvdfile=vtuIO.PVDIO("th_decovalex.pvd", dim=2)
print("time steps: ") 
print(pvdfile.timesteps)
xaxis =  [(i,0,0) for i in np.linspace(start=0.0, stop=17.5, num=100)]
r_x = np.array(xaxis)[:,0]
#time = [0.06,0.7,8.0,18.0,28.0,38.0,388.0,1000.0]
variable = "T"
for t in pvdfile.timesteps:
    function_xaxis_t = pvdfile.read_set_data(t, variable, data_type="point", pointsetarray=xaxis)
    plt.plot(r_x, function_xaxis_t, label='t='+str(t))
titlestring="TH process: FEBEX type repository"
plt.title(titlestring)
#plt.xscale('log')
plt.xlabel('x')
plt.ylabel('Temperature')
plt.legend()
plt.grid()
plt.savefig("profile.png")
plt.show()
# Out:
# Profile plot
# time steps:
# [0.00e+00 6.00e-02 7.00e-01 8.00e+00 1.80e+01 2.80e+01 3.80e+01 3.88e+02
#  1.00e+03]

# %%
theme = "Temporal plot"
print(theme)
timesteps = pvdfile.timesteps
selected_points = {}
for i in range(8):
    selected_points[f"pt{i}"] = (2*i, 0.0, 0.0)
#selected_points[f"pt0"] = (0.5, 0.0, 0.0)
variable = "T"
variable_interpolation=pvdfile.read_time_series(variable, selected_points)    
variable_pt1=variable_interpolation['pt1']
variable_pt3=variable_interpolation['pt3']
variable_pt5=variable_interpolation['pt5']
variable_pt7=variable_interpolation['pt7']
plt.plot(timesteps, variable_pt1, label='pt1')
plt.plot(timesteps, variable_pt3, label='pt3')
plt.plot(timesteps, variable_pt5, label='pt5')
plt.plot(timesteps, variable_pt5, label='pt7')
plt.legend()
plt.title(theme)
plt.xlabel('t')
plt.ylabel(variable)
plt.show()
# Out:
# Temporal plot

# %%
theme = "Vertical cross-section"
print(theme)
import matplotlib.tri as tri
file_vtu = "th_decovalex_ts_30_t_8.000000.vtu"
m_plot=vtuIO.VTUIO(file_vtu, dim=2)
triang=tri.Triangulation(m_plot.points[:,0],m_plot.points[:,1])
u_plot = m_plot.get_point_field("T")
p_plot = m_plot.get_point_field("p")
fig, ax = plt.subplots(ncols=2, figsize=(10,10))
contour_left = ax[0].tricontourf(triang, u_plot)
contour_right = ax[1].tricontourf(triang, p_plot)
fig.colorbar(contour_left,ax=ax[0],label='$T$ / [K]')
fig.colorbar(contour_right,ax=ax[1],label='$p$ / [MPa]')
plt.show()
# Out:
# Vertical cross-section

# %%
import time
print(time.ctime())
# Out:
# Sat Nov 20 00:14:59 2021

# %% [markdown]
# **Credits**
# - Wenqing and Jörg for this benchmark set up
# - Jörg Buchwald for [ogs6py](https://github.com/joergbuchwald/ogs6py) and [VTUInterface](https://github.com/joergbuchwald/VTUinterface)
# - Pierre Navaro for providing code (inspecting vtu files) https://perso.univ-rennes1.fr/pierre.navaro/read-vtk-with-python.html
# - Python framework, [matplotlib](https://matplotlib.org/)

# %% [markdown]
# **OGS links**
# - description: https://www.opengeosys.org/docs/benchmarks/hydro-thermal/decovalex-th/
# - project file: https://gitlab.opengeosys.org/ogs/ogs/-/blob/master/Tests/Data/Parabolic/HT/StaggeredCoupling/ADecovalexTHMCBasedHTExample/th_decovalex.prj
# - jupyter templates by OK (https://github.com/OlafKolditz/ogs-jupyter-lab)

# %% [markdown]
# **Test area**

# %%
##visualization
#import pyvista as pv
#grid = pv.read('.vtk')
#grid.plot(show_scalar_bar=False, show_axes=False)
#credits: stackoverflow

##multiprocessing
#jobs = []
#for i in range(5)
#    p = multiprocessing.Process(target=worker)
#    jobs.append(p)
#    p.start()
